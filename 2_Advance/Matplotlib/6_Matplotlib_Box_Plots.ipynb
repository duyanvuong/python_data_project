# %% [markdown]
# # Matplotlib Box Plot

# %% [markdown]
# Load data

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill)

# %%
# Only get data analyst jobs
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values
df_DA_US = df_DA_US.dropna(subset='salary_year_avg')

df_DA_US
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# ...

# %% [markdown]
# #### Vertical boxplot
# - vert=False

# %%
df_DA_US['salary_year_avg'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# #### Horizontal boxplot
# - No vert=False (vert=True)

# %%
df_DA_US['salary_year_avg'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Example

# %%
df_US = df[df['job_country'] == 'United States'].copy()

# %%
job_titles = list(df_US['job_title_short'].value_counts().head(3).index)

# Filter the data to the appropriate job titles
df_US = df_US[df_US['job_title_short'].isin(job_titles)]
df_US = df_US.dropna(subset='salary_year_avg')

# Get the job list
job_list = [df_US[df_US['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]

# Plotting with vertical boxplot
plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title("Salary Distribution in the United States")
plt.xlabel("Yearly Salary ($USD)")
plt.xlim(0, 650000)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${x/1000}K'))

plt.show()
# Out:
# C:\Users\duyvn\AppData\Local\Temp\ipykernel_4328\3467513135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(job_list, labels=job_titles, vert=False)

# %%
df_US['job_title_short'].value_counts().head(3)
# Out:
# job_title_short
# Data Scientist    4553
# Data Analyst      4350
# Data Engineer     2915
# Name: count, dtype: int64
